# %% [markdown]
# <a href="https://colab.research.google.com/github/jaeseong98/2024ex-tutorials-kr/blob/master/Untitled16.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
git clone https://github.com/lapis42/srtgo.git
# Out:
#   File "/tmp/ipython-input-1780720502.py", line 1
#     git clone https://github.com/lapis42/srtgo.git
#         ^
# SyntaxError: invalid syntax
